# %% [markdown]
# This exercise will require you to pull some data from the Qunadl API. Qaundl is currently the most widely used aggregator of financial market data.

# %% [markdown]
# As a first step, you will need to register a free account on the http://www.quandl.com website.

# %% [markdown]
# After you register, you will be provided with a unique API key, that you should store:

# %%
# Store the API key as a string - according to PEP8, constants are always named in all upper case
API_KEY = '8VfatBpy55sJzUnE7rFz'

# %% [markdown]
# Qaundl has a large number of data sources, but, unfortunately, most of them require a Premium subscription. Still, there are also a good number of free datasets.

# %% [markdown]
# For this mini project, we will focus on equities data from the Frankfurt Stock Exhange (FSE), which is available for free. We'll try and analyze the stock prices of a company called Carl Zeiss Meditec, which manufactures tools for eye examinations, as well as medical lasers for laser eye surgery: https://www.zeiss.com/meditec/int/home.html. The company is listed under the stock ticker AFX_X.

# %% [markdown]
# You can find the detailed Quandl API instructions here: https://docs.quandl.com/docs/time-series

# %% [markdown]
# While there is a dedicated Python package for connecting to the Quandl API, we would prefer that you use the *requests* package, which can be easily downloaded using *pip* or *conda*. You can find the documentation for the package here: http://docs.python-requests.org/en/master/

# %% [markdown]
# Finally, apart from the *requests* package, you are encouraged to not use any third party Python packages, such as *pandas*, and instead focus on what's available in the Python Standard Library (the *collections* module might come in handy: https://pymotw.com/3/collections/ ).
# Also, since you won't have access to DataFrames, you are encouraged to us Python's native data structures - preferably dictionaries, though some questions can also be answered using lists.
# You can read more on these data structures here: https://docs.python.org/3/tutorial/datastructures.html

# %% [markdown]
# Keep in mind that the JSON responses you will be getting from the API map almost one-to-one to Python's dictionaries. Unfortunately, they can be very nested, so make sure you read up on indexing dictionaries in the documentation provided above.

# %%
# First, import the relevant modules
import requests
import json

# %%
# Now, call the Quandl API and pull out a small sample of the data (only one day) to get a glimpse
# into the JSON structure that will be returned
r = requests.get("https://www.quandl.com/api/v3/datasets/FSE/AFX_X?start_date=2019-06-14&end_date=2019-06-14&api_key=" + API_KEY)

# %%
# Inspect the JSON structure of the object you created, and take note of how nested it is,
# as well as the overall structure
r.json()
# Out:
# {'dataset': {'id': 10095370,
#   'dataset_code': 'AFX_X',
#   'database_code': 'FSE',
#   'name': 'Carl Zeiss Meditec (AFX_X)',
#   'description': 'Stock Prices for Carl Zeiss Meditec (2019-09-20) from the Frankfurt Stock Exchange.<br><br>Trading System: Xetra<br><br>ISIN: DE0005313704',
#   'refreshed_at': '2019-10-04T22:26:26.506Z',
#   'newest_available_date': '2019-10-04',
#   'oldest_available_date': '2000-06-07',
#   'column_names': ['Date',
#    'Open',
#    'High',
#    'Low',
#    'Close',
#    'Change',
#    'Traded Volume',
#    'Turnover',
#    'Last Price of the Day',
#    'Daily Traded Units',
#    'Daily Turnover'],
#   'frequency': 'daily',
#   'type': 'Time Series',
#   'premium': False,
#   'limit': None,
#   'transform': None,
#   'column_index': None,
#   'start_date': '2019-06-14',
#   'end_date': '2019-06-14',
#   'data': [['2019-06-14',
#     89.0,
#     89.55,
#     88.15,
#     89.55,
#     None,
#     96679.0,
#     8632357.0,
#     None,
#     None,
# ...

# %% [markdown]
# These are your tasks for this mini project:
#
# 1. Collect data from the Franfurt Stock Exchange, for the ticker AFX_X, for the whole year 2017 (keep in mind that the date format is YYYY-MM-DD).
# 2. Convert the returned JSON object into a Python dictionary.
# 3. Calculate what the highest and lowest opening prices were for the stock in this period.
# 4. What was the largest change in any one day (based on High and Low price)?
# 5. What was the largest change between any two days (based on Closing Price)?
# 6. What was the average daily trading volume during this year?
# 7. (Optional) What was the median trading volume during this year. (Note: you may need to implement your own function for calculating the median.)

# %%
# Collect data from FSE for AFX_X for 2017 with API call
afx_2017 = requests.get("https://www.quandl.com/api/v3/datasets/FSE/AFX_X?start_date=2017-01-01&end_date=2017-12-31&api_key=" + API_KEY)

# %%
type(afx_2017)
# Out:
# requests.models.Response

# %%
# Convert JSON object into Python dict
afx_2017_dict = json.loads(afx_2017.text)
type(afx_2017_dict)
# Out:
# dict

# %%
#Calculate what the highest and lowest opening prices were for the stock in this period.
a = []
for k,v in afx_2017_dict.items():
    for k1,v1 in v.items():
        if k1=='data':
            for i in v1:
                for j in i:
                    a.append(j)

# %%
a
# Out:
# ['2017-12-29',
#  51.76,
#  51.94,
#  51.45,
#  51.76,
#  None,
#  34640.0,
#  1792304.0,
#  None,
#  None,
#  None,
#  '2017-12-28',
#  51.65,
#  51.82,
#  51.43,
#  51.6,
#  None,
#  40660.0,
#  2099024.0,
#  None,
#  None,
#  None,
#  '2017-12-27',
#  51.45,
#  51.89,
#  50.76,
#  51.82,
#  None,
#  57452.0,
#  2957018.0,
#  None,
#  None,
#  None,
#  '2017-12-22',
#  51.05,
#  51.5,
#  50.92,
#  51.32,
#  None,
#  71165.0,
#  3641949.0,
#  None,
#  None,
#  None,
#  '2017-12-21',
#  51.16,
#  51.52,
#  50.9,
#  51.4,
#  None,
#  120649.0,
#  6179433.0,
#  None,
#  None,
#  None,
#  '2017-12-20',
#  51.88,
#  52.04,
#  51.2,
#  51.27,
#  None,
#  50587.0,
#  2610258.0,
#  None,
#  None,
#  None,
#  '2017-12-19',
#  52.73,
#  52.73,
#  51.07,
#  51.66,
#  None,
#  137313.0,
#  7102361.0,
#  None,
#  None,
#  None,
#  '2017-12-18',
#  52.37,
#  52.75,
#  51.61,
#  52.62,
#  None,
#  129733.0,
#  6770499.0,
#  None,
#  None,
#  None,
#  '2017-12-15',
#  52.7,
#  52.7,
#  51.64,
# ...

# %%
b = a[1::11]

# %%
c = []
for i in b:
    if(i!=None):
        c.append(i)

# %%
print(c)
# Out:
# [51.76, 51.65, 51.45, 51.05, 51.16, 51.88, 52.73, 52.37, 52.7, 53.11, 52.64, 52.29, 52.28, 51.5, 50.89, 50.8, 51.21, 49.5, 49.52, 48.64, 49.64, 49.09, 49.13, 49.11, 48.8, 48.4, 47.25, 46.57, 47.03, 47.09, 47.98, 48.4, 48.38, 47.3, 47.65, 46.42, 46.16, 45.81, 45.0, 45.88, 46.29, 46.53, 45.48, 45.2, 45.01, 45.16, 44.9, 45.08, 45.72, 46.01, 45.8, 45.61, 45.5, 45.58, 45.97, 45.64, 46.2, 46.19, 46.01, 45.36, 44.51, 43.58, 42.0, 42.35, 42.3, 42.3, 41.48, 42.29, 42.54, 42.65, 42.5, 42.29, 42.35, 42.49, 43.21, 42.81, 42.7, 43.0, 42.66, 43.0, 42.38, 42.16, 42.0, 42.0, 41.71, 42.11, 42.64, 42.72, 42.82, 42.46, 42.42, 42.28, 41.88, 42.4, 42.53, 42.12, 41.3, 41.73, 43.5, 44.9, 45.85, 45.13, 45.34, 45.25, 45.24, 44.94, 45.26, 45.16, 44.91, 44.7, 45.31, 45.57, 45.74, 45.06, 45.5, 45.6, 45.07, 44.67, 44.29, 44.94, 44.64, 44.79, 45.5, 44.67, 45.83, 45.29, 45.01, 45.73, 46.68, 47.23, 46.95, 47.29, 47.03, 47.46, 46.48, 46.9, 45.66, 46.34, 46.52, 46.5, 47.31, 46.77, 47.8, 47.01, 47.12, 46.8, 46.12, 45.
# ...

# %%
print(max(c))
print(min(c))
# Out:
# 53.11
# 34.0

# %%
#What was the largest change in any one day (based on High and Low price)?
high = []
for k,v in afx_2017_dict.items():
    for k1,v1 in v.items():
        if k1=='data':
            for i in v1:
                for j in i:
                    high.append(j)

# %%
high = high[2::11]

# %%
high_all = []
for i in high:
    if(i!=None):
        high_all.append(i)

# %%
print(high_all)
# Out:
# [51.94, 51.82, 51.89, 51.5, 51.52, 52.04, 52.73, 52.75, 52.7, 53.54, 53.35, 53.1, 52.45, 52.83, 51.47, 51.11, 51.38, 51.23, 50.49, 49.84, 49.64, 49.89, 49.73, 49.41, 49.46, 49.61, 48.59, 47.38, 47.15, 47.23, 48.01, 48.9, 48.61, 48.89, 48.06, 47.72, 46.33, 46.09, 46.04, 46.06, 46.55, 46.65, 46.42, 45.41, 45.06, 45.27, 45.34, 45.34, 45.85, 46.2, 46.06, 45.75, 45.7, 45.58, 45.97, 46.04, 46.2, 46.19, 46.09, 46.17, 44.98, 44.17, 43.56, 42.49, 42.57, 42.3, 42.38, 42.29, 42.54, 42.65, 42.63, 42.81, 42.8, 42.69, 43.34, 42.89, 42.75, 43.02, 42.71, 43.19, 42.75, 43.06, 42.08, 42.2, 41.98, 42.25, 42.64, 43.05, 43.17, 42.96, 42.76, 42.6, 43.01, 42.62, 42.53, 42.69, 41.94, 41.99, 43.5, 45.09, 46.34, 45.13, 45.54, 45.77, 45.54, 45.75, 45.29, 45.45, 45.33, 45.04, 45.31, 45.88, 45.96, 45.72, 45.55, 46.23, 45.56, 45.18, 45.05, 44.94, 45.18, 44.79, 45.5, 45.36, 45.83, 45.83, 45.74, 45.81, 46.68, 47.33, 47.63, 47.4, 47.4, 47.48, 47.43, 46.9, 46.8, 46.34, 46.86, 46.51, 47.43, 47.44, 47.8, 47.43, 47.45, 
# ...

# %%
low = []
for k,v in afx_2017_dict.items():
    for k1,v1 in v.items():
        if k1=='data':
            for i in v1:
                for j in i:
                    low.append(j)

# %%
low = low[3::11]

# %%
low_all = []
for i in low:
    if(i!=None):
        low_all.append(i)

# %%
low_all
# Out:
# [51.45,
#  51.43,
#  50.76,
#  50.92,
#  50.9,
#  51.2,
#  51.07,
#  51.61,
#  51.64,
#  52.15,
#  52.48,
#  51.82,
#  51.26,
#  51.28,
#  50.81,
#  50.39,
#  50.4,
#  49.5,
#  49.17,
#  48.28,
#  48.7,
#  49.03,
#  48.96,
#  48.87,
#  48.45,
#  48.39,
#  46.78,
#  46.54,
#  46.8,
#  46.55,
#  46.75,
#  47.84,
#  47.76,
#  47.16,
#  47.09,
#  46.42,
#  45.84,
#  45.76,
#  44.83,
#  45.18,
#  45.97,
#  45.61,
#  45.46,
#  44.91,
#  44.7,
#  44.75,
#  44.89,
#  44.76,
#  44.79,
#  45.61,
#  45.37,
#  45.3,
#  45.37,
#  45.17,
#  45.25,
#  45.57,
#  45.6,
#  45.69,
#  45.63,
#  45.22,
#  44.18,
#  43.3,
#  42.0,
#  41.78,
#  42.11,
#  41.96,
#  41.48,
#  41.39,
#  41.99,
#  42.13,
#  42.23,
#  42.25,
#  42.35,
#  42.22,
#  42.62,
#  42.56,
#  42.56,
#  42.67,
#  42.34,
#  42.55,
#  41.95,
#  42.07,
#  41.12,
#  41.49,
#  41.33,
#  41.86,
#  42.05,
#  42.63,
#  42.6,
#  42.4,
#  42.2,
#  42.01,
#  41.76,
#  41.98,
#  42.2,
#  42.01,
#  40.96,
#  41.14,
#  41.64,
#  44.15,
#  44.02,
# ...

# %%
change = []
for i,j in zip(high_all,low_all):
    change.append(i-j)

# %%
print(max(change))
# Out:
# 2.8100000000000023

# %%
#What was the largest change between any two days (based on Closing Price)?
close = []
for k,v in afx_2017_dict.items():
    for k1,v1 in v.items():
        if k1=='data':
            for i in v1:
                for j in i:
                    close.append(j)

# %%
close = close[4::11]

# %%
max_change = [x - close[i - 1] for i, x in enumerate(close)][1:]

# %%
max(max_change)
# Out:
# 2.559999999999995

# %%
#What was the average daily trading volume during this year?
tv = []
for k,v in afx_2017_dict.items():
    for k1,v1 in v.items():
        if k1=='data':
            for i in v1:
                for j in i:
                    tv.append(j)

# %%
tv = tv[6::11]

# %%
tv
# Out:
# [34640.0,
#  40660.0,
#  57452.0,
#  71165.0,
#  120649.0,
#  50587.0,
#  137313.0,
#  129733.0,
#  204080.0,
#  132981.0,
#  128434.0,
#  87911.0,
#  71817.0,
#  109157.0,
#  48123.0,
#  88730.0,
#  83023.0,
#  94385.0,
#  101733.0,
#  123019.0,
#  67342.0,
#  42669.0,
#  102180.0,
#  50350.0,
#  38834.0,
#  91142.0,
#  78502.0,
#  97252.0,
#  54107.0,
#  89373.0,
#  67593.0,
#  67672.0,
#  76286.0,
#  90245.0,
#  120268.0,
#  94195.0,
#  48152.0,
#  60716.0,
#  56911.0,
#  37958.0,
#  56319.0,
#  56245.0,
#  74472.0,
#  56319.0,
#  47730.0,
#  43042.0,
#  43375.0,
#  55707.0,
#  59991.0,
#  45263.0,
#  65837.0,
#  49246.0,
#  43362.0,
#  49180.0,
#  69455.0,
#  65860.0,
#  44059.0,
#  66760.0,
#  94804.0,
#  115706.0,
#  95313.0,
#  99821.0,
#  157234.0,
#  76600.0,
#  51321.0,
#  56224.0,
#  79955.0,
#  105194.0,
#  57838.0,
#  65546.0,
#  44037.0,
#  107144.0,
#  65157.0,
#  68801.0,
#  52828.0,
#  103273.0,
#  59881.0,
#  64320.0,
#  71006.0,
#  66351.0,
#  105288.0,
# ...

# %%
tv_all = []
for i in tv:
    if(i!=None):
        tv_all.append(i)

# %%
tv_all
# Out:
# [34640.0,
#  40660.0,
#  57452.0,
#  71165.0,
#  120649.0,
#  50587.0,
#  137313.0,
#  129733.0,
#  204080.0,
#  132981.0,
#  128434.0,
#  87911.0,
#  71817.0,
#  109157.0,
#  48123.0,
#  88730.0,
#  83023.0,
#  94385.0,
#  101733.0,
#  123019.0,
#  67342.0,
#  42669.0,
#  102180.0,
#  50350.0,
#  38834.0,
#  91142.0,
#  78502.0,
#  97252.0,
#  54107.0,
#  89373.0,
#  67593.0,
#  67672.0,
#  76286.0,
#  90245.0,
#  120268.0,
#  94195.0,
#  48152.0,
#  60716.0,
#  56911.0,
#  37958.0,
#  56319.0,
#  56245.0,
#  74472.0,
#  56319.0,
#  47730.0,
#  43042.0,
#  43375.0,
#  55707.0,
#  59991.0,
#  45263.0,
#  65837.0,
#  49246.0,
#  43362.0,
#  49180.0,
#  69455.0,
#  65860.0,
#  44059.0,
#  66760.0,
#  94804.0,
#  115706.0,
#  95313.0,
#  99821.0,
#  157234.0,
#  76600.0,
#  51321.0,
#  56224.0,
#  79955.0,
#  105194.0,
#  57838.0,
#  65546.0,
#  44037.0,
#  107144.0,
#  65157.0,
#  68801.0,
#  52828.0,
#  103273.0,
#  59881.0,
#  64320.0,
#  71006.0,
#  66351.0,
#  105288.0,
# ...

# %%
sum(tv_all) / float(len(tv_all))
# Out:
# 89124.33725490196

# %%
#(Optional) What was the median trading volume during this year. (Note: you may need to implement your own function for calculating the median.)
def median(lst):
    n = len(lst)
    s = sorted(lst)
    return (sum(s[n//2-1:n//2+1])/2.0, s[n//2])[n % 2] if n else None

# %%
median(tv_all)
# Out:
# 76286.0
